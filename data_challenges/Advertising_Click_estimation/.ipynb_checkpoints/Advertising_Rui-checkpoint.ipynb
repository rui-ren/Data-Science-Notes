# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import missingno as msno

# %%
cwd = os.getcwd()
print(os.listdir(cwd))
# Out:
# ['.ipynb_checkpoints', 'advertising_dsdj.csv', 'Advertising_Rui.ipynb', 'Bubble map.ipynb', 'world-countries.json']

# %% [markdown]
# ## 1. Data collection and cleaning

# %%
df = pd.read_csv('advertising_dsdj.csv')

# %%
country_geo = 'world-countries.json'

# %%
df.head()
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
#
#                            Ad Topic Line            City  Male     Country  \
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
#
#           Timestamp  Clicked on Ad
# 0   2016-03-27 0:53            0.0
# ...

# %%
df.columns
# Out:
# Index(['Daily Time Spent on Site', 'Age', 'Area Income',
#        'Daily Internet Usage', 'Ad Topic Line', 'City', 'Male', 'Country',
#        'Timestamp', 'Clicked on Ad'],
#       dtype='object')

# %%
df.tail()
# Out:
#       Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 1013                     72.97   30     71384.57                208.58
# 1014                     51.30   45     67782.17                134.42
# 1015                     51.63   51     42415.72                120.37
# 1016                     55.55   19     41920.79                187.95
# 1017                     45.01   26     29875.80                178.35
#
#                              Ad Topic Line           City  Male  \
# 1013         Fundamental modular algorithm      Duffystad     1
# 1014       Grass-roots cohesive monitoring    New Darlene     1
# 1015          Expanded intangible solution  South Jessica     1
# 1016  Proactive bandwidth-monitored policy    West Steven     0
# 1017       Virtual 5thgeneration emulation    Ronniemouth     0
#
#                      Country         Timestamp  Clicked on Ad
# 1013                 Lebanon  2016-02-11 21:49            1.0
# ...

# %%
plt.figure(figsize=(10,5))
df.groupby(['Country']).mean()['Daily Time Spent on Site'].plot(c='green')

# %%
import json

with open('world-countries.json') as f:
    geo = json.load(f)

# %%
data = df.groupby(['Country']).mean()[['Daily Time Spent on Site']]
data['Country'] = data.index
data.set_index(np.arange(0, len(data)), inplace=True)

# %%
data = data.reindex(columns=['Country','Daily Time Spent on Site'])

# %%
import folium
map = folium.Map(location=[0, 0], zoom_start=1.5)

# %%
m = folium.Choropleth(
             geo_data=country_geo, 
             data=data,
             columns=['Country', 'Daily Time Spent on Site'],
             key_on='feature.properties.name',
             fill_color='YlGnBu', 
             fill_opacity=0.7,
             line_opacity=0.2,
             legend_name='Time On Line').add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 1.1 Missing value detection

# %%
df.describe()
# Out:
#        Daily Time Spent on Site          Age   Area Income  \
# count               1018.000000  1018.000000   1018.000000
# mean                  64.999921    36.936149  54983.348988
# std                   15.871054    31.566241  13445.569214
# min                   32.600000   -25.000000  13996.500000
# 25%                   51.320000    29.000000  46966.620000
# 50%                   68.105000    35.000000  57023.600000
# 75%                   78.562500    42.000000  65451.787500
# max                   91.430000   999.000000  79484.800000
#
#        Daily Internet Usage         Male  Clicked on Ad
# count           1018.000000  1018.000000    1014.000000
# mean             179.381906     0.481336       0.500986
# std               44.417978     0.499897       0.500246
# min               23.640000     0.000000       0.000000
# 25%              138.582500     0.000000       0.000000
# 50%              182.425000     0.000000       1.000000
# ...

# %%
## Describution calculation --> 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1018 entries, 0 to 1017
# Data columns (total 10 columns):
# Daily Time Spent on Site    1018 non-null float64
# Age                         1018 non-null int64
# Area Income                 1018 non-null float64
# Daily Internet Usage        1018 non-null float64
# Ad Topic Line               1018 non-null object
# City                        1018 non-null object
# Male                        1018 non-null int64
# Country                     1018 non-null object
# Timestamp                   1018 non-null object
# Clicked on Ad               1014 non-null float64
# dtypes: float64(4), int64(2), object(4)
# memory usage: 79.6+ KB

# %% [markdown]
# - As we can see, there is missing value in the data file
# - df.info() function is not that informative, and be careful with the number of `Clicked on Ad`

# %%
import seaborn as sns
df.isnull().any()
# Out:
# Daily Time Spent on Site    False
# Age                         False
# Area Income                 False
# Daily Internet Usage        False
# Ad Topic Line               False
# City                        False
# Male                        False
# Country                     False
# Timestamp                   False
# Clicked on Ad                True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Daily Time Spent on Site    0
# Age                         0
# Area Income                 0
# Daily Internet Usage        0
# Ad Topic Line               0
# City                        0
# Male                        0
# Country                     0
# Timestamp                   0
# Clicked on Ad               4
# dtype: int64

# %% [markdown]
# - Visualization for the dataset

# %%
msno.matrix(df, figsize=(10,3))

# %%
sns.heatmap(df.isnull() == True, cbar=False, yticklabels=False, cmap='plasma')

# %%
df[df['Clicked on Ad'].isnull() == True]
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 131                     67.36   37     73104.47                233.56
# 217                     67.28   43     76246.96                155.80
# 431                     34.30   41     53167.68                160.74
# 722                     46.89   48     72553.94                176.78
#
#                                   Ad Topic Line                 City  Male  \
# 131  Future-proofed grid-enabled implementation  North Wesleychester     0
# 217            Future-proofed coherent hardware       North Mercedes     1
# 431      Re-contextualized reciprocal interface     West Melaniefurt     1
# 722        Polarized mission-critical structure           Chaseshire     1
#
#                     Country         Timestamp  Clicked on Ad
# 131                  Jersey  2016-07-06 16:00            NaN
# 217                Pakistan  2016-04-03 21:13            NaN
# ...

# %% [markdown]
# * Drop NAN value

# %%
df.dropna(inplace=True)

# %%
df.isnull().any()
# Out:
# Daily Time Spent on Site    False
# Age                         False
# Area Income                 False
# Daily Internet Usage        False
# Ad Topic Line               False
# City                        False
# Male                        False
# Country                     False
# Timestamp                   False
# Clicked on Ad               False
# dtype: bool

# %%
df.shape
# Out:
# (1014, 10)

# %% [markdown]
# - Now the dataset has 1014 training set, and 9 features plus 1 label

# %% [markdown]
# ### 1.2 Distribution and outlier detection

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(), cmap='Blues', annot=False)

# %% [markdown]
# - Outlier checking

# %%
df.columns
# Out:
# Index(['Daily Time Spent on Site', 'Age', 'Area Income',
#        'Daily Internet Usage', 'Ad Topic Line', 'City', 'Male', 'Country',
#        'Timestamp', 'Clicked on Ad'],
#       dtype='object')

# %%
plt.figure(figsize=(10,5))
l = df.columns.values[:4]
number_of_columns = 5
# we have 1 label in the dataset
number_of_rows = (len(l))/number_of_columns
plt.figure(figsize=(1.5*number_of_columns, 5*number_of_rows))

for i in range(0, len(l)):
    plt.subplot(number_of_rows+1, number_of_columns, i+1)
    ax = plt.gca()
    ax.yaxis.grid(True, which='Major', linestyle='--')
    sns.set_style('whitegrid')
    sns.boxplot(df[l[i]], color='green', orient='v')
plt.tight_layout()

# %% [markdown]
# - As we can see that, the outliers are in Age and Area Income
# - Get the outlier using IQR

# %% [markdown]
# - The distribution of the Age

# %%
sns.distplot(df['Age'])

# %% [markdown]
# - The right skewed Area Income

# %%
sns.distplot(df['Area Income'])

# %% [markdown]
# - Define IQR outlier remove method for the calculation

# %% [markdown]
# ## WHY INTRODUCE THE NAN VALUE ???

# %%
# We define a outlier remove function

def iqr_outlier_rm(df_input):
    # use the np.percentile as the indicator
    # lq, uq = np.percentile(df_input, [25, 75])
    quantile = df_input.quantile([.25, .75], axis=0)
    lq, uq = quantile.iloc[0], quantile.iloc[1]
    IQR = uq - lq
    lower = lq - 1.5 * IQR
    upper = uq + 1.5 * IQR
    
    # be aware that the slice numpy or pandas using bool --> df[[True, True, False]]
    # inside is a lit
    # we need to transfer the time series data into list
    
    # This is not slice according to index
    
    # slice according to the element --> be aware of that delete the NAN value
    return df_input[(df_input >= lower) & (df_input <= upper)].dropna()

# %%
# remove outlier in the dataframe

# %%
list(pd.Series([True, False]) & pd.Series([True, False]))
# Out:
# [True, False]

# %%
df_outlier_rm = iqr_outlier_rm(df[df.columns[:4]])

# %% [markdown]
# - Look at the data, there is no problem at all

# %%
df_outlier_rm.isnull().sum()
# Out:
# Daily Time Spent on Site    0
# Age                         0
# Area Income                 0
# Daily Internet Usage        0
# dtype: int64

# %%
plt.figure(figsize=(10,5))
l = df_outlier_rm.columns.values
number_of_columns = 5
# we have 1 label in the dataset
number_of_rows = (len(l))/number_of_columns
plt.figure(figsize=(1.5*number_of_columns, 5*number_of_rows))

for i in range(0, len(l)):
    plt.subplot(number_of_rows+1, number_of_columns, i+1)
    ax = plt.gca()
    ax.yaxis.grid(True, which='Major', linestyle='--')
    sns.set_style('whitegrid')
    sns.boxplot(df_outlier_rm[l[i]], color='green', orient='v')
plt.tight_layout()

# %%
df_outlier_rm['Age'].min()
# Out:
# 19.0

# %%
df_outlier_rm.shape
# Out:
# (1001, 4)

# %%
sns.distplot(df_outlier_rm['Age'])

# %%
df_outlier_rm['Age'].skew()
# Out:
# 0.48745902406801506

# %%
sns.distplot(df_outlier_rm['Area Income'])

# %% [markdown]
# ### 2.1 Define data visualization figure

# %%
# show the info of the data
def data_info(data):
    return data.info()

def creating_boxplots(size, target, features, data):
    plt.figure(figsize=size)
    for i in range(len(features)):
        plt.subplot(5, 3, i+1)
        sns.boxplot(x=target, y=features[i], data=data)

def creating_distplot(size, data, features):
    plt.figure(figsize=size)
    for i in range(len(features)):
        plt.subplot(5, 3, i+1)
        sns.distplot(data[features[i]])

def crossCorrelation(data):
    corr = data.corr()
    plt.figure(figsize=(10,6))
    sns.heatmap(corr,
                cmap='Blues',
                xticklabels=corr.columns.values,
                yticklabels=corr.columns.values)

# %% [markdown]
# ## 3. Exploray Data Analysis

# %%
df_new = pd.concat([df_outlier_rm, df[df.columns[4:]]], axis=1).dropna()

# %%
num_vars = df_new.select_dtypes(exclude=['object', 'datetime64']).columns

# %%
num_vars
# Out:
# Index(['Daily Time Spent on Site', 'Age', 'Area Income',
#        'Daily Internet Usage', 'Male', 'Clicked on Ad'],
#       dtype='object')

# %%
# get rid of the daily internet usage < actually daily time spend on site
df_new['delta'] = df_new['Daily Internet Usage'] - df_new['Daily Time Spent on Site']

# %%
df_new = df_new[df_new['delta'] >= 0]
# df_new = df_new.drop('delta', axis=1)

# %%
creating_distplot((16,18), df_new, num_vars)

# %%
target = "Clicked on Ad"
creating_boxplots((16,18), target, num_vars, df_new)

# %%
crossCorrelation(df_new)

# %% [markdown]
# ### 3.3.3 Distribution plot with respect to Target Feature

# %% [markdown]
# #### !!Numerical data we look at the distribution

# %%
plt.rcParams["patch.force_edgecolor"] = False

# %%
# subsetting by clicks
click_yes = df_new["Clicked on Ad"] == 1
click_no = df_new["Clicked on Ad"] == 0

# creating the plots
features = ["Daily Internet Usage", "Daily Time Spent on Site", "Area Income", "Age"]
labels = ["Click", "No Click"]

def creating_plots(features, labels):
    plt.figure(figsize=(16, 8))
    for feature in features:
        plt.subplot(2, 2, features.index(feature)+1)
        sns.distplot(df_new[feature][click_yes], label=labels[0], color='y')
        sns.distplot(df_new[feature][click_no], label=labels[1], color='b')
        plt.axvline(df_new[feature][click_yes].mean(), linestyle="--", color="y")
        plt.axvline(df_new[feature][click_no].mean(), linestyle='--', color='b')
        plt.legend()
        plt.grid(False)
    
    plt.tight_layout()

# %%
creating_plots(features, labels)

# %% [markdown]
# #### ! For categorical data we look at the number

# %%
table_country = pd.crosstab(index=df_new["Country"],
                           columns="count")
table_country.sort_values(["count"], ascending=False).head(10)
# Out:
# col_0                   count
# Country
# Madagascar                  9
# France                      9
# Czech Republic              9
# Afghanistan                 8
# Bosnia and Herzegovina      8
# Turkey                      8
# South Africa                8
# Senegal                     8
# Peru                        8
# Micronesia                  8

# %%
table_clicked_country = pd.crosstab(df_new["Country"],
                                    df_new["Clicked on Ad"], 
                                    rownames=["Country"],
                                    colnames=["Clicked On Ad"])

table_clicked_country.sort_values(1, 0, ascending=False).head(10)
# Out:
# Clicked On Ad  0.0  1.0
# Country
# Australia        1    7
# Turkey           1    7
# Liechtenstein    0    7
# Ethiopia         0    7
# Liberia          2    6
# South Africa     2    6
# Senegal          3    5
# Peru             3    5
# Mayotte          1    5
# Hungary          1    5

# %% [markdown]
# ## 3.2.5 Pair plots with respect To our Target Feature

# %%
df_new.columns
# Out:
# Index(['Daily Time Spent on Site', 'Age', 'Area Income',
#        'Daily Internet Usage', 'Ad Topic Line', 'City', 'Male', 'Country',
#        'Timestamp', 'Clicked on Ad'],
#       dtype='object')

# %%
sns.set_style("whitegrid", {'axes.grid' : False})
plt.figure()
customized_feature = ['Daily Time Spent on Site', 'Age', 'Area Income', 'Daily Internet Usage']
sns.pairplot(data=df_new,
             vars = customized_feature,
             hue="Clicked on Ad",
             dropna=True)

# %% [markdown]
# ### For the skewed data, we use the log transformation

# %% [markdown]
# ## 3 Feature Engineering

# %% [markdown]
# ### 3.1 Skewed Features: Log Transform

# %% [markdown]
# - The data of age feature is right skewed, there has three method to solve the skewed data:
#     * Logarithmic transformation --> after transformation -0.07
#     * Square root transformation --> after transformation 0.24
#     * Box-Cox transformation --> after transformation -0.0006 --> reduce the data size

# %%
# cox box transformation
# from scipy import stats
# pd.Series(stats.boxcox(df_new["Age"])[0]).skew()

# # np.sqrt() transformation
# np.sqrt(df_new["Age"]).skew()

# # np.log() transformation
# np.log(df_new["Age"]).skew()

# %%
df_new = df_new.drop(['cox_age'], axis=1)

# %% [markdown]
# #### Right now drop the `Ad Topic Line`, Later I will apply Natural Language Process method to the analysis

# %%
df = df_new.drop(["Ad Topic Line", "Timestamp", "City"], axis=1)

# %%
df
# Out:
#       Daily Time Spent on Site   Age  Area Income  Daily Internet Usage  Male  \
# 0                        68.95  35.0     61833.90                256.09     0
# 1                        80.23  31.0     68441.85                193.77     1
# 2                        69.47  26.0     59785.94                236.50     0
# 3                        74.15  29.0     54806.18                245.89     1
# 4                        68.37  35.0     73889.99                225.58     0
# 5                        59.99  23.0     59761.56                226.74     1
# 6                        88.91  33.0     53852.85                208.36     0
# 7                        66.00  48.0     24593.33                131.76     1
# 8                        74.53  30.0     68862.00                221.51     1
# 9                        69.88  20.0     55642.32                183.82     1
# 10                       47.64  49.0     45632.51                122.02     0
# ...

# %% [markdown]
# #### Normalization of Numerical Features

# %%
categorical_vars = ["Ad Topic Line", "City", "Country"]
numerical_vars = ["Daily Time Spent on Site", "Area Income", "Daily Internet Usage", "Male", "log_age"]
datatime_vars = "Timestamp"
target = "Clicked on Ad"

# %% [markdown]
# - Import a module

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, make_scorer, fbeta_score
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
# Initialize a scaler, then apply it to the featuers
scaler = MinMaxScaler()

# Applying the MinMax transformation of the numerical variables
data = pd.DataFrame(data=df)
data[numerical_vars] = scaler.fit_transform(data[numerical_vars])

# %%
data.head(10)
# Out:
#    Daily Time Spent on Site   Age  Area Income  Daily Internet Usage  Male  \
# 0                  0.617882  35.0     0.703312              0.916031   0.0
# 1                  0.809621  31.0     0.814383              0.538746   1.0
# 2                  0.626721  26.0     0.668888              0.797433   0.0
# 3                  0.706272  29.0     0.585185              0.854280   1.0
# 4                  0.608023  35.0     0.905959              0.731323   0.0
# 5                  0.465579  23.0     0.668478              0.738346   1.0
# 6                  0.957165  33.0     0.569161              0.627073   0.0
# 7                  0.567738  48.0     0.077347              0.163337   1.0
# 8                  0.712732  30.0     0.821445              0.706684   1.0
# 9                  0.633690  20.0     0.599239              0.478508   1.0
#
#       Country  Clicked on Ad   log_age
# 0     Tunisia            0.0  0.523740
# 1       Nauru            0.0  0.419696
# ...

# %% [markdown]
# ### 3.3.4 Processing categorical feature: One Hot-Encoding

# %%
final_data = pd.get_dummies(data)

# %%
s = pd.Series(list('abcd'))
